# %%
#1.sales

# %%
import pandas as pd
df1 = pd.read_csv("Sales.csv")
df1
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# 0            366000          1   1/1/2016           NaN       265598
# 1            366001          1   1/1/2016     1/13/2016      1269051
# 2            366001          2   1/1/2016     1/13/2016      1269051
# 3            366002          1   1/1/2016     1/12/2016       266019
# 4            366002          2   1/1/2016     1/12/2016       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1  2/20/2021           NaN      1216913
# 62880       2243031          1  2/20/2021     2/24/2021       511229
# 62881       2243032          1  2/20/2021     2/23/2021       331277
# 62882       2243032          2  2/20/2021     2/23/2021       331277
# 62883       2243032          3  2/20/2021     2/23/2021       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# 0            10        1304         1           CAD
# ...

# %%
df1['Order Date'] = pd.to_datetime(df1['Order Date'], errors='coerce')
df1['Delivery Date'] = pd.to_datetime(df1['Delivery Date'], errors='coerce')
df1['Delivery Date']=df1['Delivery Date'].fillna(0)
df1['Currency Code']=df1['Currency Code'].astype(str)
df1.index.name='s_no'

sales_df = df1

# %%
sales_df
# Out:
#        Order Number  Line Item Order Date Delivery Date  CustomerKey  \
# s_no
# 0            366000          1 2016-01-01    1970-01-01       265598
# 1            366001          1 2016-01-01    2016-01-13      1269051
# 2            366001          2 2016-01-01    2016-01-13      1269051
# 3            366002          1 2016-01-01    2016-01-12       266019
# 4            366002          2 2016-01-01    2016-01-12       266019
# ...             ...        ...        ...           ...          ...
# 62879       2243030          1 2021-02-20    1970-01-01      1216913
# 62880       2243031          1 2021-02-20    2021-02-24       511229
# 62881       2243032          1 2021-02-20    2021-02-23       331277
# 62882       2243032          2 2021-02-20    2021-02-23       331277
# 62883       2243032          3 2021-02-20    2021-02-23       331277
#
#        StoreKey  ProductKey  Quantity Currency Code
# s_no
# 0            10        1304         1           CAD
# ...

# %%
#2.customers

# %%
import pandas as pd
df2 = pd.read_csv('Customers.csv', encoding='ISO-8859-1')
# Replace problematic characters
df2
# Out:
#        CustomerKey  Gender               Name                 City State Code  \
# 0              301  Female      Lilly Harding       WANDEARAH EAST         SA
# 1              325  Female       Madison Hull           MOUNT BUDD         WA
# 2              554  Female      Claire Ferres            WINJALLOK        VIC
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER         SA
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH        VIC
# ...            ...     ...                ...                  ...        ...
# 15261      2099600  Female     Denisa Duková              Houston         TX
# 15262      2099618    Male   Justin Solórzano               Mclean         VA
# 15263      2099758    Male    Svend Petrussen           Wilmington         NC
# 15264      2099862  Female       Lorenza Rush            Riverside         CA
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township         MI
#
# ...

# %%
df2['Birthday'] = pd.to_datetime(df2['Birthday'], errors='coerce')
df2.index.name='s_no'
df2=df2.drop(columns=['State Code','Zip Code'])

Customers_df=df2

# %%
Customers_df
# Out:
#        CustomerKey  Gender               Name                 City  \
# s_no
# 0              301  Female      Lilly Harding       WANDEARAH EAST
# 1              325  Female       Madison Hull           MOUNT BUDD
# 2              554  Female      Claire Ferres            WINJALLOK
# 3              786    Male  Jai Poltpalingada         MIDDLE RIVER
# 4             1042    Male    Aidan Pankhurst        TAWONGA SOUTH
# ...            ...     ...                ...                  ...
# 15261      2099600  Female     Denisa Duková              Houston
# 15262      2099618    Male   Justin Solórzano               Mclean
# 15263      2099758    Male    Svend Petrussen           Wilmington
# 15264      2099862  Female       Lorenza Rush            Riverside
# 15265      2099937    Male   Zygmunt Kaminski  Bloomfield Township
#
#                    State        Country      Continent   Birthday
# s_no
# 0        South Australia      Australia      Australia 1939-07-03
# ...

# %%
#3. products

# %%
import pandas as pd
df3=pd.read_csv("Products.csv")
df3.index.name='s_no'

# Step 2: Remove unwanted characters (dollar signs, periods, spaces, commas)
df3['Unit Cost USD'] = df3['Unit Cost USD'].replace({r'\$': '', r'\.': '', r',': '', r'\s+': ''}, regex=True)
df3['Unit Price USD'] = df3['Unit Price USD'].replace({r'\$': '', r'\.': '', r',': '', r'\s+': ''}, regex=True)

# Step 3: Convert to numeric (float), setting errors='coerce' to handle invalid data gracefully
df3['Unit Cost USD'] = pd.to_numeric(df3['Unit Cost USD'], errors='coerce')
df3['Unit Price USD'] = pd.to_numeric(df3['Unit Price USD'], errors='coerce')

Products_df=df3

# %%
Products_df
# Out:
#       ProductKey                                   Product Name    Brand  \
# s_no
# 0              1            Contoso 512MB MP3 Player E51 Silver  Contoso
# 1              2              Contoso 512MB MP3 Player E51 Blue  Contoso
# 2              3               Contoso 1G MP3 Player E100 White  Contoso
# 3              4              Contoso 2G MP3 Player E200 Silver  Contoso
# 4              5                 Contoso 2G MP3 Player E200 Red  Contoso
# ...          ...                                            ...      ...
# 2512        2513    Contoso Bluetooth Active Headphones L15 Red  Contoso
# 2513        2514  Contoso Bluetooth Active Headphones L15 White  Contoso
# 2514        2515             Contoso In-Line Coupler E180 White  Contoso
# 2515        2516             Contoso In-Line Coupler E180 Black  Contoso
# 2516        2517            Contoso In-Line Coupler E180 Silver  Contoso
#
#        Color  Unit Cost USD  Unit Price USD  SubcategoryKey  \
# s_no
# ...

# %%
#4. stores

# %%
import pandas as pd
df4=pd.read_csv('Stores.csv')
df4
# Out:
#     StoreKey        Country                         State  Square Meters  \
# 0          1      Australia  Australian Capital Territory          595.0
# 1          2      Australia            Northern Territory          665.0
# 2          3      Australia               South Australia         2000.0
# 3          4      Australia                      Tasmania         2000.0
# 4          5      Australia                      Victoria         2000.0
# ..       ...            ...                           ...            ...
# 62        63  United States                          Utah         2000.0
# 63        64  United States                 Washington DC         1330.0
# 64        65  United States                 West Virginia         1785.0
# 65        66  United States                       Wyoming          840.0
# 66         0         Online                        Online            NaN
#
#     Open Date
# 0    1/1/2008
# 1   1/12/2008
# 2    1/7/2012
# 3    1/1/2010
# ...

# %%
df4['Square Meters']=df4['Square Meters'].fillna(0)
df4['Open Date'] = pd.to_datetime(df4['Open Date'], errors='coerce')
df4.index.name='s_no'
Stores_df=df4

# %%
Stores_df
# Out:
#       StoreKey        Country                         State  Square Meters  \
# s_no
# 0            1      Australia  Australian Capital Territory          595.0
# 1            2      Australia            Northern Territory          665.0
# 2            3      Australia               South Australia         2000.0
# 3            4      Australia                      Tasmania         2000.0
# 4            5      Australia                      Victoria         2000.0
# ...        ...            ...                           ...            ...
# 62          63  United States                          Utah         2000.0
# 63          64  United States                 Washington DC         1330.0
# 64          65  United States                 West Virginia         1785.0
# 65          66  United States                       Wyoming          840.0
# 66           0         Online                        Online            0.0
#
#       Open Date
# s_no
# 0    2008-01-01
# 1    2008-01-12
# ...

# %%
# 5. Exchange rates

# %%
import pandas as pd
df5=pd.read_csv('Exchange_Rates.csv')
df5
# Out:
#             Date Currency  Exchange
# 0       1/1/2015      USD    1.0000
# 1       1/1/2015      CAD    1.1583
# 2       1/1/2015      AUD    1.2214
# 3       1/1/2015      EUR    0.8237
# 4       1/1/2015      GBP    0.6415
# ...          ...      ...       ...
# 11210  2/20/2021      USD    1.0000
# 11211  2/20/2021      CAD    1.2610
# 11212  2/20/2021      AUD    1.2723
# 11213  2/20/2021      EUR    0.8238
# 11214  2/20/2021      GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
df5.info()
df5['Date'] = pd.to_datetime(df5['Date'], errors='coerce')
df5 = df5.rename(columns={'Currency': 'Currency Code'})
df5.index.name='s_no'
Exchange_Rates_df=df5

# %%
Exchange_Rates_df
# Out:
#             Date Currency Code  Exchange
# s_no
# 0     2015-01-01           USD    1.0000
# 1     2015-01-01           CAD    1.1583
# 2     2015-01-01           AUD    1.2214
# 3     2015-01-01           EUR    0.8237
# 4     2015-01-01           GBP    0.6415
# ...          ...           ...       ...
# 11210 2021-02-20           USD    1.0000
# 11211 2021-02-20           CAD    1.2610
# 11212 2021-02-20           AUD    1.2723
# 11213 2021-02-20           EUR    0.8238
# 11214 2021-02-20           GBP    0.7126
#
# [11215 rows x 3 columns]

# %%
import pandas as pd
import psycopg2

# Assuming df is your DataFrame

# Connect to PostgreSQL
con = psycopg2.connect(
    database="homedb",
    user="postgres",
    password="mukisam290",
    host="localhost",  # e.g., 'localhost'
    port="5432"        # Default PostgreSQL port
)

cursor = con.cursor()

# Create table if it doesn't exist
create_table_query = """
CREATE TABLE IF NOT EXISTS sales_info (
    id SERIAL PRIMARY KEY,
    "Order Number" INT,
    "Line Item" INT,
    "Order Date" Date,
    "Delivery Date" Date,
    "CustomerKey" INT,
    "StoreKey" INT,
    "ProductKey" INT,
    "Quantity" INT,
    "Currency Code" VARCHAR(50)
    
);
"""

# Execute the CREATE TABLE query
cursor.execute(create_table_query)
con.commit()

insert_query = """
INSERT INTO sales_info (
   "Order Number" ,"Line Item" , "Order Date", "Delivery Date" ,"CustomerKey","StoreKey","ProductKey","Quantity",
    "Currency Code" 
) VALUES (%s, %s, %s, %s, %s ,%s ,%s ,%s,%s);
"""

# Convert DataFrame to a list of tuples
df1_list = sales_df.values.tolist()

# Insert data into the table
for row in df1_list:
    cursor.execute(insert_query, row)

# Commit the changes
con.commit()

# Close the cursor and connection
cursor.close()
con.close()

print("Table inserted successfully!")
# Out:
# Table inserted successfully!

# %%
import pandas as pd
import psycopg2

# Assuming df is your DataFrame

# Connect to PostgreSQL
con = psycopg2.connect(
    database="homedb",
    user="postgres",
    password="mukisam290",
    host="localhost",  # e.g., 'localhost'
    port="5432"        # Default PostgreSQL port
)

cursor = con.cursor()

# Create table if it doesn't exist
create_table_query = """
CREATE TABLE IF NOT EXISTS products_info (
    id SERIAL PRIMARY KEY,
    "ProductKey" INT,
    "Product Name" VARCHAR(100),
    "Brand" VARCHAR(100),
    "Color" VARCHAR(50),
    "Unit Cost USD" NUMERIC(10, 2),
    "Unit Price USD" NUMERIC(10, 2),
    "SubcategoryKey" INT,
    "Subcategory" VARCHAR(100),
    "CategoryKey" INT,
    "Category" VARCHAR(100)
    
);
"""

# Execute the CREATE TABLE query
cursor.execute(create_table_query)
con.commit()

insert_query = """
INSERT INTO products_info (
  "ProductKey" , 
  "Product Name" , "Brand" , "Color" , "Unit Cost USD" , "Unit Price USD" ,"SubcategoryKey",
    "Subcategory" ,"CategoryKey" , "Category"
     
) VALUES (%s, %s, %s, %s, %s,%s,%s,%s,%s,%s);
"""

# Convert DataFrame to a list of tuples
df3_list = Products_df.values.tolist()

# Insert data into the table
for row in df3_list:
    cursor.execute(insert_query, row)

# Commit the changes
con.commit()

# Close the cursor and connection
cursor.close()
con.close()

print("Table inserted successfully!")
# Out:
# Table inserted successfully!

# %%
import pandas as pd
import psycopg2

# Assuming df is your DataFrame

# Connect to PostgreSQL
con = psycopg2.connect(
    database="homedb",
    user="postgres",
    password="mukisam290",
    host="localhost",  # e.g., 'localhost'
    port="5432"        # Default PostgreSQL port
)

cursor = con.cursor()

# Create table if it doesn't exist
create_table_query = """
CREATE TABLE IF NOT EXISTS customers_info (
    id SERIAL PRIMARY KEY,
    "CustomerKey" INT,
    "Gender" VARCHAR(10),
    "Name" VARCHAR(100),
    "City" VARCHAR(100),
    "State" VARCHAR(100),
    "Country" VARCHAR(100),
    "Continent" VARCHAR(100),
    "Birthday" DATE
    
);
"""

# Execute the CREATE TABLE query
cursor.execute(create_table_query)
con.commit()

insert_query = """
INSERT INTO customers_info (
  "CustomerKey", "Gender" , "Name" , "City" , "State" ,  "Country" ,
    "Continent" ,"Birthday"   
) VALUES (%s, %s, %s, %s, %s,%s,%s,%s);
"""

# Convert DataFrame to a list of tuples
df2_list = Customers_df.values.tolist()

# Insert data into the table
for row in df2_list:
    cursor.execute(insert_query, row)

# Commit the changes
con.commit()

# Close the cursor and connection
cursor.close()
con.close()

print("Table inserted successfully!")
# Out:
# Table inserted successfully!

# %%
import pandas as pd
import psycopg2

# Assuming df is your DataFrame

# Connect to PostgreSQL
con = psycopg2.connect(
    database="homedb",
    user="postgres",
    password="mukisam290",
    host="localhost",  # e.g., 'localhost'
    port="5432"        # Default PostgreSQL port
)

cursor = con.cursor()

# Create table if it doesn't exist
create_table_query = """
CREATE TABLE IF NOT EXISTS store_info (
    id SERIAL PRIMARY KEY,
    "StoreKey" INT,
    "Country" VARCHAR(100),
    "State" VARCHAR(100),
    "SquareMetres" NUMERIC(10, 2),
    "OpenDate" DATE
);
"""

# Execute the CREATE TABLE query
cursor.execute(create_table_query)
con.commit()

insert_query = """
INSERT INTO store_info (
    "StoreKey", "Country", "State", "SquareMetres", "OpenDate"
) VALUES (%s, %s, %s, %s, %s);
"""

# Convert DataFrame to a list of tuples
df_list = Stores_df.values.tolist()

# Insert data into the table
for row in df_list:
    cursor.execute(insert_query, row)

# Commit the changes
con.commit()

# Close the cursor and connection
cursor.close()
con.close()

print("Data inserted successfully!")
# Out:
# Data inserted successfully!

# %%
import pandas as pd
import psycopg2

# Assuming df is your DataFrame

# Connect to PostgreSQL
con = psycopg2.connect(
    database="homedb",
    user="postgres",
    password="mukisam290",
    host="localhost",  # e.g., 'localhost'
    port="5432"        # Default PostgreSQL port
)

cursor = con.cursor()

# Create table if it doesn't exist
create_table_query = """
CREATE TABLE IF NOT EXISTS exchange_rates_info (
    id SERIAL PRIMARY KEY,
    "Date" Date,
    "Currency Code" VARCHAR(100),
    "Exchange" REAL
);
"""

# Execute the CREATE TABLE query
cursor.execute(create_table_query)
con.commit()

insert_query = """
INSERT INTO exchange_rates_info (
    "Date", "Currency Code", "Exchange"
) VALUES (%s, %s, %s);
"""

# Convert DataFrame to a list of tuples
df_list = Exchange_Rates_df.values.tolist()

# Insert data into the table
for row in df_list:
    cursor.execute(insert_query, row)

# Commit the changes
con.commit()

# Close the cursor and connection
cursor.close()
con.close()

print("Data inserted successfully!")
# Out:
# Data inserted successfully!
